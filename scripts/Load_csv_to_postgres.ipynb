# %%
import pandas as pd
import psycopg2
from psycopg2 import sql, extras
from psycopg2.extras import execute_values

from dotenv import load_dotenv
import os
import pandas as pd

# %%
load_dotenv()

# Datos de conexión
db_host = os.getenv('DB_HOST')
db_port = os.getenv('DB_PORT')
db_name = os.getenv('DB_NAME')
db_user = os.getenv('DB_USER')
db_password = os.getenv('DB_PASSWORD')

# Ruta al CSV
csv_file = '/Users/marcelomiqueljuan/Documents/Projects/My Town Weather Analysis/Input/st_antoni.csv'  # ⚡ pon la ruta correcta aquí

# Leer el CSV
df = pd.read_csv(csv_file)

# %%
df['dt_iso']
# Out:
# 0         1979-01-01 00:00:00 +0000 UTC
# 1         1979-01-01 01:00:00 +0000 UTC
# 2         1979-01-01 02:00:00 +0000 UTC
# 3         1979-01-01 03:00:00 +0000 UTC
# 4         1979-01-01 04:00:00 +0000 UTC
#                       ...
# 405427    2025-04-01 19:00:00 +0000 UTC
# 405428    2025-04-01 20:00:00 +0000 UTC
# 405429    2025-04-01 21:00:00 +0000 UTC
# 405430    2025-04-01 22:00:00 +0000 UTC
# 405431    2025-04-01 23:00:00 +0000 UTC
# Name: dt_iso, Length: 405432, dtype: object

# %%
# Step 1: Remove the ' UTC' part from the datetime strings
df['dt_iso'] = df['dt_iso'].str.replace(' UTC', '', regex=False)

# Step 2: Convert the cleaned string to datetime with UTC timezone
df['dt_iso'] = pd.to_datetime(df['dt_iso'], utc=True)

# %%
# Mapeo para que pandas coincida con la tabla
df = df.rename(columns={
    'city_name': 'city_name',
    'lat': 'lat',
    'lon': 'lon',
    'temp': 'temp',
    'temp_min': 'temp_min',
    'temp_max': 'temp_max',
    'feels_like': 'feels_like',
    'pressure': 'pressure',
    'humidity': 'humidity',
    'dew_point': 'dew_point',
    'wind_speed': 'wind_speed',
    'wind_deg': 'wind_deg',
    'wind_gust': 'wind_gust',
    'clouds_all': 'cloudiness',
    'rain_1h': 'rain_1h',
    'rain_3h': 'rain_3h',
    'snow_1h': 'snow_1h',
    'snow_3h': 'snow_3h',
    'weather_id': 'weather_id',
    'weather_main': 'weather_main',
    'weather_description': 'weather_description',
    'weather_icon': 'weather_icon',
    'visibility': 'visibility',
    'dt': 'dt',
    'dt_iso': 'dt_iso',
    'timezone': 'timezone'
})

# Solo las columnas que tenemos en la tabla
expected_cols = [
    'city_name', 'lat', 'lon', 'temp', 'temp_min', 'temp_max', 'feels_like',
    'pressure', 'humidity', 'dew_point', 'wind_speed', 'wind_deg', 'wind_gust',
    'cloudiness', 'rain_1h', 'rain_3h', 'snow_1h', 'snow_3h', 'weather_id',
    'weather_main', 'weather_description', 'weather_icon', 'visibility',
    'dt', 'dt_iso', 'timezone'
]
df = df[expected_cols]

# Conexión a la base de datos
conn = psycopg2.connect(
    host=db_host,
    database=db_name,
    user=db_user,
    password=db_password,
    port=db_port
)

# %%
cur = conn.cursor()
cur.execute('SET search_path TO public')
# Prepare list of tuples
data = [tuple(row) for row in df[expected_cols].values]

# %%
cur = conn.cursor()
cur.execute('SELECT current_database();')
print('👉 Connected to:', cur.fetchone())
# Out:
# 👉 Connected to: ('weather_project_db',)

# %%
# Prepare the insert statement
insert_query = sql.SQL("""
    INSERT INTO stg_weather_data ({fields})
    VALUES ({placeholders})
""").format(
    fields=sql.SQL(', ').join(map(sql.Identifier, expected_cols)),
    placeholders=sql.SQL(', ').join(sql.Placeholder() * len(expected_cols))
)

# Clean and prepare data
df = df[expected_cols].where(pd.notnull(df), None)
df['visibility'] = df['visibility'].apply(lambda x: int(x) if pd.notnull(x) else None)

# Convert the dataframe to a list of tuples
data_tuples = [tuple(x) for x in df[expected_cols].to_numpy()]

# Batch insert setup
batch_size = 5000

for i in range(0, len(data_tuples), batch_size):
    batch = data_tuples[i:i + batch_size]
    try:
        extras.execute_batch(cur, insert_query, batch)
        conn.commit()
        print(f"✅ Inserted batch {i // batch_size + 1}: rows {i} to {i + len(batch) - 1}")
    except Exception as e:
        print(f"❌ Error inserting batch starting at row {i}")
        print("Error message:", e)
        conn.rollback()
        break  # You can change this to continue if you want to skip errors

cur.close()
conn.close()

print("✅ All batches processed successfully")
# Out:
# ✅ Inserted batch 1: rows 0 to 4999
# ✅ Inserted batch 2: rows 5000 to 9999
# ✅ Inserted batch 3: rows 10000 to 14999
# ✅ Inserted batch 4: rows 15000 to 19999
# ✅ Inserted batch 5: rows 20000 to 24999
# ✅ Inserted batch 6: rows 25000 to 29999
# ✅ Inserted batch 7: rows 30000 to 34999
# ✅ Inserted batch 8: rows 35000 to 39999
# ✅ Inserted batch 9: rows 40000 to 44999
# ✅ Inserted batch 10: rows 45000 to 49999
# ✅ Inserted batch 11: rows 50000 to 54999
# ✅ Inserted batch 12: rows 55000 to 59999
# ✅ Inserted batch 13: rows 60000 to 64999
# ✅ Inserted batch 14: rows 65000 to 69999
# ✅ Inserted batch 15: rows 70000 to 74999
# ✅ Inserted batch 16: rows 75000 to 79999
# ✅ Inserted batch 17: rows 80000 to 84999
# ✅ Inserted batch 18: rows 85000 to 89999
# ✅ Inserted batch 19: rows 90000 to 94999
# ✅ Inserted batch 20: rows 95000 to 99999
# ✅ Inserted batch 21: rows 100000 to 104999
# ✅ Inserted batch 22: rows 105000 to 109999
# ✅ Inserted batch 23: rows 110000 to 114999
# ✅ Inserted batch 24: rows 115000 to 119999
# ✅ Inserted batch 25: rows 120000 to 124999
# ✅ Inserted batch 26: rows 125000 to 129999
# ✅ Inserted batch 27: rows 130000 to 134999
# ✅ Inserted batch 28: rows 135000 to 139999
# ✅ Inserted batch 29: rows 140000 to 144999
# ✅ Inserted batch 30: rows 145000 to 149999
# ✅ Inserted batch 31: rows 150000 to 154999
# ✅ Inserted batch 32: rows 155000 to 159999
# ✅ Inserted batch 33: rows 160000 to 164999
# ✅ Inserted batch 34: rows 165000 to 169999
# ✅ Inserted batch 35: rows 170000 to 174999
# ✅ Inserted batch 36: rows 175000 to 179999
# ✅ Inserted batch 37: rows 180000 to 184999
# ✅ Inserted batch 38: rows 185000 to 189999
# ✅ Inserted batch 39: rows 190000 to 194999
# ✅ Inserted batch 40: rows 195000 to 199999
# ✅ Inserted batch 41: rows 200000 to 204999
# ✅ Inserted batch 42: rows 205000 to 209999
# ✅ Inserted batch 43: rows 210000 to 214999
# ✅ Inserted batch 44: rows 215000 to 219999
# ✅ Inserted batch 45: rows 220000 to 224999
# ✅ Inserted batch 46: rows 225000 to 229999
# ✅ Inserted batch 47: rows 230000 to 234999
# ✅ Inserted batch 48: rows 235000 to 239999
# ✅ Inserted batch 49: rows 240000 to 244999
# ✅ Inserted batch 50: rows 245000 to 249999
# ✅ Inserted batch 51: rows 250000 to 254999
# ✅ Inserted batch 52: rows 255000 to 259999
# ✅ Inserted batch 53: rows 260000 to 264999
# ✅ Inserted batch 54: rows 265000 to 269999
# ✅ Inserted batch 55: rows 270000 to 274999
# ✅ Inserted batch 56: rows 275000 to 279999
# ✅ Inserted batch 57: rows 280000 to 284999
# ✅ Inserted batch 58: rows 285000 to 289999
# ✅ Inserted batch 59: rows 290000 to 294999
# ✅ Inserted batch 60: rows 295000 to 299999
# ✅ Inserted batch 61: rows 300000 to 304999
# ✅ Inserted batch 62: rows 305000 to 309999
# ✅ Inserted batch 63: rows 310000 to 314999
# ✅ Inserted batch 64: rows 315000 to 319999
# ✅ Inserted batch 65: rows 320000 to 324999
# ✅ Inserted batch 66: rows 325000 to 329999
# ✅ Inserted batch 67: rows 330000 to 334999
# ✅ Inserted batch 68: rows 335000 to 339999
# ✅ Inserted batch 69: rows 340000 to 344999
# ✅ Inserted batch 70: rows 345000 to 349999
# ✅ Inserted batch 71: rows 350000 to 354999
# ✅ Inserted batch 72: rows 355000 to 359999
# ✅ Inserted batch 73: rows 360000 to 364999
# ✅ Inserted batch 74: rows 365000 to 369999
# ✅ Inserted batch 75: rows 370000 to 374999
# ✅ Inserted batch 76: rows 375000 to 379999
# ✅ Inserted batch 77: rows 380000 to 384999
# ✅ Inserted batch 78: rows 385000 to 389999
# ✅ Inserted batch 79: rows 390000 to 394999
# ✅ Inserted batch 80: rows 395000 to 399999
# ✅ Inserted batch 81: rows 400000 to 404999
# ✅ Inserted batch 82: rows 405000 to 405431
# ✅ All batches processed successfully

# %%
data_tuples
# Out:
# [('Sant Antoni',
#   38.553135,
#   -0.506159,
#   13.21,
#   11.59,
#   14.23,
#   12.31,
#   1017,
#   66,
#   7.0,
#   4.72,
#   276,
#   nan,
#   13,
#   nan,
#   nan,
#   nan,
#   nan,
#   801,
#   'Clouds',
#   'few clouds',
#   '02n',
#   None,
#   283996800,
#   Timestamp('1979-01-01 00:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   13.25,
#   11.75,
#   14.22,
#   12.46,
#   1016,
#   70,
#   7.9,
#   4.76,
#   277,
#   nan,
#   14,
#   nan,
#   nan,
#   nan,
#   nan,
#   801,
#   'Clouds',
#   'few clouds',
#   '02n',
#   None,
#   284000400,
#   Timestamp('1979-01-01 01:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   13.37,
#   11.88,
#   14.41,
#   12.62,
#   1016,
#   71,
#   8.23,
#   4.21,
#   275,
#   nan,
#   26,
#   nan,
#   nan,
#   nan,
#   nan,
#   802,
#   'Clouds',
#   'scattered clouds',
#   '03n',
#   None,
#   284004000,
#   Timestamp('1979-01-01 02:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.25,
#   10.07,
#   13.45,
#   11.33,
#   1016,
#   69,
#   6.74,
#   3.92,
#   276,
#   nan,
#   46,
#   nan,
#   nan,
#   nan,
#   nan,
#   802,
#   'Clouds',
#   'scattered clouds',
#   '03n',
#   None,
#   284007600,
#   Timestamp('1979-01-01 03:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.84,
#   10.07,
#   13.08,
#   10.91,
#   1016,
#   70,
#   6.55,
#   3.96,
#   279,
#   nan,
#   52,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   284011200,
#   Timestamp('1979-01-01 04:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.78,
#   10.07,
#   13.06,
#   10.84,
#   1016,
#   70,
#   6.49,
#   4.1,
#   284,
#   nan,
#   62,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   284014800,
#   Timestamp('1979-01-01 05:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.83,
#   10.25,
#   13.15,
#   10.87,
#   1017,
#   69,
#   6.33,
#   3.76,
#   278,
#   nan,
#   94,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284018400,
#   Timestamp('1979-01-01 06:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.33,
#   11.33,
#   12.86,
#   10.37,
#   1018,
#   71,
#   6.27,
#   3.19,
#   270,
#   nan,
#   70,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   284022000,
#   Timestamp('1979-01-01 07:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.38,
#   9.62,
#   12.86,
#   10.48,
#   1019,
#   73,
#   6.72,
#   2.99,
#   269,
#   nan,
#   33,
#   nan,
#   nan,
#   nan,
#   nan,
#   802,
#   'Clouds',
#   'scattered clouds',
#   '03d',
#   None,
#   284025600,
#   Timestamp('1979-01-01 08:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.01,
#   9.62,
#   12.13,
#   10.07,
#   1020,
#   73,
#   6.36,
#   3.17,
#   268,
#   nan,
#   35,
#   nan,
#   nan,
#   nan,
#   nan,
#   802,
#   'Clouds',
#   'scattered clouds',
#   '03d',
#   None,
#   284029200,
#   Timestamp('1979-01-01 09:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.87,
#   14.52,
#   16.64,
#   14.97,
#   1020,
#   56,
#   7.12,
#   3.68,
#   258,
#   nan,
#   76,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04d',
#   None,
#   284032800,
#   Timestamp('1979-01-01 10:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.92,
#   14.67,
#   16.57,
#   14.95,
#   1019,
#   53,
#   6.36,
#   4.95,
#   267,
#   nan,
#   17,
#   nan,
#   nan,
#   nan,
#   nan,
#   801,
#   'Clouds',
#   'few clouds',
#   '02d',
#   None,
#   284036400,
#   Timestamp('1979-01-01 11:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   16.12,
#   14.92,
#   16.72,
#   15.15,
#   1019,
#   52,
#   6.27,
#   5.54,
#   268,
#   nan,
#   20,
#   nan,
#   nan,
#   nan,
#   nan,
#   801,
#   'Clouds',
#   'few clouds',
#   '02d',
#   None,
#   284040000,
#   Timestamp('1979-01-01 12:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   16.18,
#   15.04,
#   16.76,
#   15.19,
#   1018,
#   51,
#   6.05,
#   5.94,
#   267,
#   nan,
#   45,
#   nan,
#   nan,
#   nan,
#   nan,
#   802,
#   'Clouds',
#   'scattered clouds',
#   '03d',
#   None,
#   284043600,
#   Timestamp('1979-01-01 13:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   16.2,
#   15.06,
#   16.79,
#   15.21,
#   1018,
#   51,
#   6.06,
#   5.92,
#   272,
#   nan,
#   18,
#   nan,
#   nan,
#   nan,
#   nan,
#   801,
#   'Clouds',
#   'few clouds',
#   '02d',
#   None,
#   284047200,
#   Timestamp('1979-01-01 14:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.69,
#   15.03,
#   17.07,
#   14.72,
#   1016,
#   54,
#   6.42,
#   5.12,
#   272,
#   nan,
#   3,
#   nan,
#   nan,
#   nan,
#   nan,
#   800,
#   'Clear',
#   'sky is clear',
#   '01d',
#   None,
#   284050800,
#   Timestamp('1979-01-01 15:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.87,
#   15.31,
#   17.07,
#   14.95,
#   1017,
#   55,
#   6.85,
#   4.23,
#   272,
#   nan,
#   31,
#   nan,
#   nan,
#   nan,
#   nan,
#   802,
#   'Clouds',
#   'scattered clouds',
#   '03d',
#   None,
#   284054400,
#   Timestamp('1979-01-01 16:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.3,
#   15.07,
#   15.41,
#   14.32,
#   1017,
#   55,
#   6.32,
#   3.5,
#   272,
#   nan,
#   20,
#   nan,
#   nan,
#   nan,
#   nan,
#   801,
#   'Clouds',
#   'few clouds',
#   '02n',
#   None,
#   284058000,
#   Timestamp('1979-01-01 17:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.58,
#   14.07,
#   16.45,
#   14.68,
#   1018,
#   57,
#   7.1,
#   3.24,
#   274,
#   nan,
#   70,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   284061600,
#   Timestamp('1979-01-01 18:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   14.68,
#   12.94,
#   15.79,
#   13.64,
#   1019,
#   55,
#   5.75,
#   3.01,
#   278,
#   nan,
#   48,
#   nan,
#   nan,
#   nan,
#   nan,
#   802,
#   'Clouds',
#   'scattered clouds',
#   '03n',
#   None,
#   284065200,
#   Timestamp('1979-01-01 19:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   14.82,
#   13.06,
#   16.07,
#   13.82,
#   1019,
#   56,
#   6.14,
#   2.76,
#   280,
#   nan,
#   38,
#   nan,
#   nan,
#   nan,
#   nan,
#   802,
#   'Clouds',
#   'scattered clouds',
#   '03n',
#   None,
#   284068800,
#   Timestamp('1979-01-01 20:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.61,
#   10.67,
#   13.07,
#   10.65,
#   1019,
#   70,
#   6.33,
#   2.93,
#   276,
#   nan,
#   80,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   284072400,
#   Timestamp('1979-01-01 21:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.64,
#   10.6,
#   12.24,
#   10.66,
#   1018,
#   69,
#   6.15,
#   2.75,
#   276,
#   nan,
#   86,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284076000,
#   Timestamp('1979-01-01 22:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.89,
#   10.67,
#   12.73,
#   10.94,
#   1018,
#   69,
#   6.39,
#   2.97,
#   282,
#   nan,
#   99,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284079600,
#   Timestamp('1979-01-01 23:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.28,
#   12.07,
#   12.36,
#   11.42,
#   1018,
#   71,
#   7.18,
#   2.88,
#   290,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284083200,
#   Timestamp('1979-01-02 00:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.74,
#   12.07,
#   13.69,
#   11.98,
#   1017,
#   73,
#   8.03,
#   2.47,
#   297,
#   nan,
#   99,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284086800,
#   Timestamp('1979-01-02 01:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.93,
#   12.07,
#   13.83,
#   12.24,
#   1017,
#   75,
#   8.61,
#   2.34,
#   306,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284090400,
#   Timestamp('1979-01-02 02:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.3,
#   9.66,
#   12.35,
#   10.47,
#   1017,
#   76,
#   7.23,
#   2.02,
#   307,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284094000,
#   Timestamp('1979-01-02 03:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.46,
#   9.75,
#   12.53,
#   10.65,
#   1016,
#   76,
#   7.38,
#   1.99,
#   309,
#   nan,
#   86,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284097600,
#   Timestamp('1979-01-02 04:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.75,
#   9.58,
#   13.29,
#   10.99,
#   1017,
#   77,
#   7.86,
#   2.39,
#   316,
#   nan,
#   71,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   284101200,
#   Timestamp('1979-01-02 05:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.29,
#   9.26,
#   12.71,
#   10.54,
#   1017,
#   79,
#   7.79,
#   2.21,
#   310,
#   nan,
#   64,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   284104800,
#   Timestamp('1979-01-02 06:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.36,
#   10.07,
#   11.61,
#   10.69,
#   1018,
#   82,
#   8.4,
#   1.95,
#   312,
#   nan,
#   62,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   284108400,
#   Timestamp('1979-01-02 07:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.47,
#   10.07,
#   12.16,
#   10.81,
#   1019,
#   82,
#   8.51,
#   1.9,
#   319,
#   nan,
#   92,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284112000,
#   Timestamp('1979-01-02 08:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.76,
#   9.33,
#   11.5,
#   9.95,
#   1021,
#   79,
#   7.27,
#   2.55,
#   330,
#   nan,
#   90,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284115600,
#   Timestamp('1979-01-02 09:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   14.17,
#   13.07,
#   14.31,
#   13.39,
#   1022,
#   67,
#   8.14,
#   3.5,
#   2,
#   nan,
#   88,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284119200,
#   Timestamp('1979-01-02 10:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   14.9,
#   14.46,
#   15.49,
#   14.22,
#   1023,
#   68,
#   9.05,
#   3.31,
#   25,
#   nan,
#   69,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04d',
#   None,
#   284122800,
#   Timestamp('1979-01-02 11:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.08,
#   14.63,
#   15.6,
#   14.42,
#   1023,
#   68,
#   9.23,
#   2.5,
#   43,
#   nan,
#   73,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04d',
#   None,
#   284126400,
#   Timestamp('1979-01-02 12:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.03,
#   14.64,
#   15.27,
#   14.42,
#   1023,
#   70,
#   9.61,
#   2.11,
#   64,
#   nan,
#   89,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284130000,
#   Timestamp('1979-01-02 13:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.2,
#   13.07,
#   15.31,
#   14.68,
#   1023,
#   73,
#   10.4,
#   2.7,
#   91,
#   nan,
#   89,
#   0.11,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10d',
#   None,
#   284133600,
#   Timestamp('1979-01-02 14:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.88,
#   12.07,
#   13.08,
#   12.52,
#   1023,
#   88,
#   10.94,
#   3.02,
#   102,
#   nan,
#   96,
#   0.12,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10d',
#   None,
#   284137200,
#   Timestamp('1979-01-02 15:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.55,
#   11.72,
#   13.07,
#   12.34,
#   1024,
#   95,
#   11.77,
#   3.22,
#   108,
#   nan,
#   100,
#   0.35,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10d',
#   None,
#   284140800,
#   Timestamp('1979-01-02 16:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.27,
#   11.07,
#   12.83,
#   12.06,
#   1025,
#   96,
#   11.65,
#   2.96,
#   107,
#   nan,
#   100,
#   0.15,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284144400,
#   Timestamp('1979-01-02 17:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.33,
#   9.33,
#   11.07,
#   7.82,
#   1026,
#   97,
#   8.88,
#   2.82,
#   102,
#   nan,
#   100,
#   0.27,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284148000,
#   Timestamp('1979-01-02 18:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.57,
#   10.92,
#   12.38,
#   11.32,
#   1027,
#   97,
#   11.11,
#   3.26,
#   102,
#   nan,
#   100,
#   0.7,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284151600,
#   Timestamp('1979-01-02 19:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.41,
#   10.73,
#   12.27,
#   11.11,
#   1027,
#   96,
#   10.8,
#   3.53,
#   105,
#   nan,
#   100,
#   0.84,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284155200,
#   Timestamp('1979-01-02 20:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.87,
#   8.07,
#   9.06,
#   6.68,
#   1028,
#   95,
#   8.11,
#   3.87,
#   110,
#   nan,
#   100,
#   0.49,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284158800,
#   Timestamp('1979-01-02 21:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.4,
#   7.96,
#   9.06,
#   6.47,
#   1028,
#   98,
#   8.1,
#   3.2,
#   108,
#   nan,
#   100,
#   0.33,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284162400,
#   Timestamp('1979-01-02 22:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.2,
#   7.78,
#   8.91,
#   5.94,
#   1029,
#   98,
#   7.9,
#   3.71,
#   107,
#   nan,
#   100,
#   0.32,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284166000,
#   Timestamp('1979-01-02 23:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.89,
#   7.4,
#   8.72,
#   5.72,
#   1029,
#   97,
#   7.44,
#   3.42,
#   114,
#   nan,
#   100,
#   0.29,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284169600,
#   Timestamp('1979-01-03 00:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.77,
#   7.25,
#   8.6,
#   5.45,
#   1029,
#   97,
#   7.32,
#   3.65,
#   120,
#   nan,
#   100,
#   0.32,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284173200,
#   Timestamp('1979-01-03 01:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.8,
#   7.26,
#   8.68,
#   5.52,
#   1029,
#   96,
#   7.2,
#   3.58,
#   120,
#   nan,
#   100,
#   0.3,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284176800,
#   Timestamp('1979-01-03 02:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.64,
#   7.92,
#   9.62,
#   6.34,
#   1029,
#   94,
#   7.73,
#   3.98,
#   122,
#   nan,
#   100,
#   0.33,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284180400,
#   Timestamp('1979-01-03 03:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.65,
#   7.91,
#   9.67,
#   6.43,
#   1028,
#   94,
#   7.74,
#   3.83,
#   127,
#   nan,
#   96,
#   0.38,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284184000,
#   Timestamp('1979-01-03 04:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.6,
#   7.87,
#   9.57,
#   6.35,
#   1027,
#   95,
#   7.85,
#   3.87,
#   133,
#   nan,
#   100,
#   0.44,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284187600,
#   Timestamp('1979-01-03 05:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   6.33,
#   6.33,
#   7.86,
#   3.66,
#   1027,
#   95,
#   5.59,
#   3.7,
#   136,
#   nan,
#   100,
#   0.38,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284191200,
#   Timestamp('1979-01-03 06:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.05,
#   7.07,
#   8.2,
#   5.84,
#   1027,
#   93,
#   6.99,
#   3.55,
#   138,
#   nan,
#   100,
#   0.17,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284194800,
#   Timestamp('1979-01-03 07:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.89,
#   7.07,
#   8.03,
#   5.69,
#   1027,
#   93,
#   6.83,
#   3.48,
#   141,
#   nan,
#   100,
#   0.12,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10d',
#   None,
#   284198400,
#   Timestamp('1979-01-03 08:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.11,
#   5.85,
#   7.93,
#   4.64,
#   1027,
#   90,
#   5.58,
#   3.65,
#   145,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284202000,
#   Timestamp('1979-01-03 09:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.24,
#   7.92,
#   9.99,
#   7.14,
#   1025,
#   82,
#   6.33,
#   3.86,
#   161,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284205600,
#   Timestamp('1979-01-03 10:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.08,
#   7.71,
#   9.99,
#   6.7,
#   1025,
#   83,
#   6.35,
#   4.38,
#   169,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284209200,
#   Timestamp('1979-01-03 11:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.66,
#   9.07,
#   9.88,
#   7.23,
#   1023,
#   82,
#   6.74,
#   4.82,
#   171,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284212800,
#   Timestamp('1979-01-03 12:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.75,
#   7.41,
#   9.67,
#   6.19,
#   1021,
#   82,
#   5.85,
#   4.61,
#   176,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284216400,
#   Timestamp('1979-01-03 13:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.55,
#   7.24,
#   9.45,
#   6.1,
#   1020,
#   82,
#   5.66,
#   4.26,
#   180,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284220000,
#   Timestamp('1979-01-03 14:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.92,
#   9.07,
#   10.23,
#   8.05,
#   1018,
#   81,
#   6.82,
#   3.68,
#   177,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284223600,
#   Timestamp('1979-01-03 15:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.91,
#   9.07,
#   10.19,
#   8.19,
#   1017,
#   82,
#   6.99,
#   3.39,
#   179,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284227200,
#   Timestamp('1979-01-03 16:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.16,
#   7.7,
#   10.21,
#   7.58,
#   1017,
#   85,
#   6.77,
#   2.88,
#   187,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284230800,
#   Timestamp('1979-01-03 17:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.28,
#   7.86,
#   10.3,
#   7.92,
#   1016,
#   87,
#   7.23,
#   2.57,
#   201,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284234400,
#   Timestamp('1979-01-03 18:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.1,
#   7.07,
#   10.2,
#   7.9,
#   1015,
#   87,
#   7.05,
#   2.31,
#   213,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284238000,
#   Timestamp('1979-01-03 19:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.54,
#   7.07,
#   9.72,
#   7.29,
#   1014,
#   89,
#   6.83,
#   2.24,
#   225,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284241600,
#   Timestamp('1979-01-03 20:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.21,
#   5.84,
#   8.47,
#   5.7,
#   1013,
#   88,
#   5.36,
#   2.27,
#   232,
#   nan,
#   99,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284245200,
#   Timestamp('1979-01-03 21:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.74,
#   6.07,
#   8.95,
#   6.29,
#   1012,
#   92,
#   6.52,
#   2.31,
#   235,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284248800,
#   Timestamp('1979-01-03 22:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.8,
#   6.07,
#   9.08,
#   6.17,
#   1011,
#   92,
#   6.58,
#   2.57,
#   239,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284252400,
#   Timestamp('1979-01-03 23:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.96,
#   6.07,
#   9.32,
#   6.26,
#   1010,
#   91,
#   6.58,
#   2.7,
#   240,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284256000,
#   Timestamp('1979-01-04 00:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.19,
#   6.07,
#   9.69,
#   6.4,
#   1009,
#   90,
#   6.65,
#   2.91,
#   243,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284259600,
#   Timestamp('1979-01-04 01:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.65,
#   7.28,
#   10.06,
#   6.97,
#   1007,
#   89,
#   6.94,
#   2.88,
#   246,
#   nan,
#   96,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284263200,
#   Timestamp('1979-01-04 02:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.86,
#   7.07,
#   10.19,
#   7.23,
#   1006,
#   85,
#   6.48,
#   2.86,
#   250,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284266800,
#   Timestamp('1979-01-04 03:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.9,
#   7.67,
#   10.2,
#   7.48,
#   1005,
#   84,
#   6.35,
#   2.56,
#   255,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284270400,
#   Timestamp('1979-01-04 04:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.21,
#   7.89,
#   10.59,
#   7.96,
#   1005,
#   83,
#   6.48,
#   2.4,
#   271,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284274000,
#   Timestamp('1979-01-04 05:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.32,
#   7.07,
#   11.86,
#   8.22,
#   1005,
#   82,
#   6.41,
#   2.23,
#   288,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284277600,
#   Timestamp('1979-01-04 06:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.09,
#   8.57,
#   11.45,
#   9.32,
#   1006,
#   83,
#   7.34,
#   2.58,
#   287,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284281200,
#   Timestamp('1979-01-04 07:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.13,
#   9.04,
#   11.08,
#   9.31,
#   1005,
#   81,
#   7.02,
#   3.35,
#   274,
#   nan,
#   97,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284284800,
#   Timestamp('1979-01-04 08:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.92,
#   9.07,
#   10.53,
#   7.93,
#   1006,
#   74,
#   5.51,
#   3.94,
#   265,
#   nan,
#   99,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284288400,
#   Timestamp('1979-01-04 09:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.98,
#   10.89,
#   12.72,
#   10.85,
#   1005,
#   62,
#   4.93,
#   5.08,
#   266,
#   nan,
#   97,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284292000,
#   Timestamp('1979-01-04 10:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.08,
#   10.84,
#   13.06,
#   10.99,
#   1006,
#   63,
#   5.26,
#   6.09,
#   267,
#   nan,
#   96,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284295600,
#   Timestamp('1979-01-04 11:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.64,
#   12.07,
#   13.07,
#   11.68,
#   1005,
#   66,
#   6.46,
#   5.65,
#   268,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284299200,
#   Timestamp('1979-01-04 12:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.41,
#   11.99,
#   12.82,
#   11.51,
#   1004,
#   69,
#   6.89,
#   5.34,
#   268,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284302800,
#   Timestamp('1979-01-04 13:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.28,
#   11.86,
#   12.71,
#   11.42,
#   1003,
#   71,
#   7.18,
#   4.79,
#   264,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284306400,
#   Timestamp('1979-01-04 14:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.63,
#   10.17,
#   11.08,
#   9.65,
#   1004,
#   73,
#   6.0,
#   4.15,
#   260,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284310000,
#   Timestamp('1979-01-04 15:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.88,
#   10.47,
#   11.28,
#   9.9,
#   1004,
#   72,
#   6.04,
#   3.69,
#   261,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284313600,
#   Timestamp('1979-01-04 16:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.48,
#   9.24,
#   11.53,
#   9.46,
#   1005,
#   72,
#   5.65,
#   2.71,
#   264,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284317200,
#   Timestamp('1979-01-04 17:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.33,
#   10.07,
#   11.86,
#   9.3,
#   1004,
#   72,
#   5.51,
#   1.91,
#   264,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284320800,
#   Timestamp('1979-01-04 18:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.66,
#   9.07,
#   11.78,
#   9.69,
#   1005,
#   73,
#   6.03,
#   1.69,
#   278,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284324400,
#   Timestamp('1979-01-04 19:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.96,
#   9.07,
#   12.06,
#   10.02,
#   1005,
#   73,
#   6.31,
#   1.59,
#   281,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284328000,
#   Timestamp('1979-01-04 20:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.54,
#   7.24,
#   9.5,
#   7.77,
#   1006,
#   78,
#   4.93,
#   1.7,
#   277,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284331600,
#   Timestamp('1979-01-04 21:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.95,
#   8.07,
#   9.87,
#   8.37,
#   1006,
#   81,
#   5.87,
#   1.58,
#   287,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284335200,
#   Timestamp('1979-01-04 22:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.02,
#   7.75,
#   8.28,
#   7.13,
#   1006,
#   83,
#   5.31,
#   1.74,
#   297,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284338800,
#   Timestamp('1979-01-04 23:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.81,
#   7.06,
#   8.8,
#   6.84,
#   1006,
#   86,
#   5.62,
#   1.79,
#   314,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284342400,
#   Timestamp('1979-01-05 00:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.34,
#   6.73,
#   8.34,
#   6.27,
#   1005,
#   88,
#   5.49,
#   1.82,
#   322,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284346000,
#   Timestamp('1979-01-05 01:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.54,
#   7.04,
#   8.47,
#   6.56,
#   1005,
#   87,
#   5.52,
#   1.76,
#   322,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284349600,
#   Timestamp('1979-01-05 02:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.34,
#   7.07,
#   7.37,
#   6.27,
#   1006,
#   88,
#   5.49,
#   1.82,
#   328,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284353200,
#   Timestamp('1979-01-05 03:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.23,
#   6.18,
#   7.84,
#   6.37,
#   1006,
#   86,
#   5.05,
#   1.6,
#   337,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284356800,
#   Timestamp('1979-01-05 04:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.45,
#   6.39,
#   8.11,
#   6.6,
#   1005,
#   86,
#   5.26,
#   1.62,
#   339,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284360400,
#   Timestamp('1979-01-05 05:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.04,
#   7.33,
#   8.21,
#   7.37,
#   1006,
#   87,
#   6.01,
#   1.54,
#   333,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284364000,
#   Timestamp('1979-01-05 06:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.02,
#   7.86,
#   8.18,
#   7.18,
#   1007,
#   87,
#   5.99,
#   1.69,
#   330,
#   nan,
#   100,
#   0.1,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284367600,
#   Timestamp('1979-01-05 07:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.87,
#   7.76,
#   8.07,
#   6.89,
#   1008,
#   87,
#   5.84,
#   1.81,
#   332,
#   nan,
#   100,
#   0.11,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10d',
#   None,
#   284371200,
#   Timestamp('1979-01-05 08:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.79,
#   6.9,
#   8.26,
#   6.7,
#   1008,
#   79,
#   4.38,
#   1.91,
#   335,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284374800,
#   Timestamp('1979-01-05 09:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.38,
#   8.07,
#   9.92,
#   8.46,
#   1009,
#   80,
#   6.11,
#   2.01,
#   340,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284378400,
#   Timestamp('1979-01-05 10:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.33,
#   8.07,
#   9.85,
#   8.46,
#   1009,
#   77,
#   5.51,
#   1.94,
#   341,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284382000,
#   Timestamp('1979-01-05 11:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.97,
#   7.99,
#   9.47,
#   7.56,
#   1009,
#   78,
#   5.35,
#   2.56,
#   349,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284385600,
#   Timestamp('1979-01-05 12:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.86,
#   7.84,
#   9.4,
#   7.24,
#   1007,
#   80,
#   5.6,
#   2.84,
#   357,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284389200,
#   Timestamp('1979-01-05 13:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.12,
#   8.01,
#   9.73,
#   7.7,
#   1007,
#   80,
#   5.86,
#   2.62,
#   6,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284392800,
#   Timestamp('1979-01-05 14:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.51,
#   7.41,
#   9.07,
#   7.05,
#   1007,
#   81,
#   5.44,
#   2.51,
#   13,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284396400,
#   Timestamp('1979-01-05 15:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.55,
#   7.45,
#   9.12,
#   7.25,
#   1008,
#   86,
#   6.34,
#   2.31,
#   17,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284400000,
#   Timestamp('1979-01-05 16:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.79,
#   7.07,
#   9.39,
#   7.75,
#   1009,
#   89,
#   7.08,
#   2.04,
#   11,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284403600,
#   Timestamp('1979-01-05 17:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.95,
#   7.83,
#   9.53,
#   7.73,
#   1009,
#   90,
#   7.4,
#   2.3,
#   2,
#   nan,
#   100,
#   0.34,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284407200,
#   Timestamp('1979-01-05 18:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.07,
#   7.8,
#   9.87,
#   7.7,
#   1010,
#   90,
#   7.52,
#   2.53,
#   356,
#   nan,
#   100,
#   1.23,
#   nan,
#   nan,
#   nan,
#   501,
#   'Rain',
#   'moderate rain',
#   '10n',
#   None,
#   284410800,
#   Timestamp('1979-01-05 19:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   9.21,
#   8.07,
#   9.87,
#   7.75,
#   1010,
#   89,
#   7.49,
#   2.71,
#   359,
#   nan,
#   100,
#   0.8,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284414400,
#   Timestamp('1979-01-05 20:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.79,
#   6.82,
#   8.29,
#   5.72,
#   1011,
#   89,
#   6.09,
#   3.22,
#   360,
#   nan,
#   100,
#   0.91,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284418000,
#   Timestamp('1979-01-05 21:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.81,
#   7.79,
#   8.07,
#   5.81,
#   1012,
#   92,
#   6.59,
#   3.12,
#   357,
#   nan,
#   99,
#   0.23,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284421600,
#   Timestamp('1979-01-05 22:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.04,
#   8.02,
#   8.07,
#   6.01,
#   1012,
#   93,
#   6.98,
#   3.24,
#   356,
#   nan,
#   98,
#   0.13,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284425200,
#   Timestamp('1979-01-05 23:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.36,
#   8.07,
#   8.38,
#   6.42,
#   1013,
#   93,
#   7.3,
#   3.2,
#   355,
#   nan,
#   98,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284428800,
#   Timestamp('1979-01-06 00:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.35,
#   8.07,
#   8.44,
#   6.24,
#   1013,
#   93,
#   7.29,
#   3.49,
#   5,
#   nan,
#   96,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284432400,
#   Timestamp('1979-01-06 01:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   7.82,
#   6.78,
#   8.46,
#   5.53,
#   1013,
#   94,
#   6.92,
#   3.61,
#   12,
#   nan,
#   97,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284436000,
#   Timestamp('1979-01-06 02:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.14,
#   7.07,
#   8.77,
#   5.83,
#   1014,
#   93,
#   7.08,
#   3.78,
#   14,
#   nan,
#   98,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284439600,
#   Timestamp('1979-01-06 03:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.07,
#   7.07,
#   8.64,
#   5.73,
#   1014,
#   94,
#   7.16,
#   3.8,
#   10,
#   nan,
#   95,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284443200,
#   Timestamp('1979-01-06 04:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.02,
#   7.0,
#   8.55,
#   5.68,
#   1015,
#   94,
#   7.11,
#   3.79,
#   5,
#   nan,
#   92,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284446800,
#   Timestamp('1979-01-06 05:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.63,
#   8.6,
#   9.07,
#   6.33,
#   1015,
#   94,
#   7.72,
#   3.97,
#   4,
#   nan,
#   92,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284450400,
#   Timestamp('1979-01-06 06:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.33,
#   8.33,
#   10.86,
#   5.84,
#   1016,
#   94,
#   7.42,
#   4.22,
#   7,
#   nan,
#   96,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284454000,
#   Timestamp('1979-01-06 07:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.49,
#   8.29,
#   9.07,
#   5.86,
#   1017,
#   93,
#   7.42,
#   4.62,
#   12,
#   nan,
#   93,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284457600,
#   Timestamp('1979-01-06 08:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.9,
#   8.06,
#   10.07,
#   6.19,
#   1018,
#   90,
#   7.35,
#   5.07,
#   20,
#   nan,
#   91,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284461200,
#   Timestamp('1979-01-06 09:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.42,
#   10.53,
#   12.4,
#   10.86,
#   1019,
#   86,
#   9.16,
#   5.48,
#   21,
#   nan,
#   89,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284464800,
#   Timestamp('1979-01-06 10:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.03,
#   10.1,
#   12.07,
#   10.46,
#   1020,
#   87,
#   8.95,
#   5.72,
#   25,
#   nan,
#   85,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284468400,
#   Timestamp('1979-01-06 11:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.43,
#   9.31,
#   12.07,
#   9.83,
#   1020,
#   88,
#   8.53,
#   6.4,
#   28,
#   nan,
#   92,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284472000,
#   Timestamp('1979-01-06 12:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.58,
#   9.59,
#   12.12,
#   9.94,
#   1019,
#   86,
#   8.34,
#   6.97,
#   31,
#   nan,
#   93,
#   0.14,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10d',
#   None,
#   284475600,
#   Timestamp('1979-01-06 13:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.54,
#   9.52,
#   12.09,
#   9.95,
#   1019,
#   88,
#   8.64,
#   6.65,
#   30,
#   nan,
#   94,
#   0.12,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10d',
#   None,
#   284479200,
#   Timestamp('1979-01-06 14:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.46,
#   9.42,
#   12.07,
#   9.91,
#   1020,
#   90,
#   8.89,
#   6.36,
#   28,
#   nan,
#   93,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284482800,
#   Timestamp('1979-01-06 15:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.51,
#   9.44,
#   12.09,
#   9.99,
#   1020,
#   91,
#   9.1,
#   6.1,
#   29,
#   nan,
#   93,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284486400,
#   Timestamp('1979-01-06 16:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.89,
#   9.65,
#   12.53,
#   10.49,
#   1021,
#   94,
#   9.96,
#   6.28,
#   34,
#   nan,
#   97,
#   0.11,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284490000,
#   Timestamp('1979-01-06 17:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.74,
#   10.02,
#   11.47,
#   10.3,
#   1021,
#   93,
#   9.66,
#   6.0,
#   40,
#   nan,
#   99,
#   0.21,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284493600,
#   Timestamp('1979-01-06 18:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.12,
#   10.32,
#   11.84,
#   10.72,
#   1022,
#   93,
#   10.03,
#   6.05,
#   45,
#   nan,
#   100,
#   0.24,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284497200,
#   Timestamp('1979-01-06 19:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.41,
#   10.52,
#   12.16,
#   11.03,
#   1022,
#   93,
#   10.32,
#   6.17,
#   50,
#   nan,
#   100,
#   0.3,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284500800,
#   Timestamp('1979-01-06 20:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.14,
#   9.36,
#   11.19,
#   9.66,
#   1022,
#   94,
#   9.22,
#   6.36,
#   53,
#   nan,
#   96,
#   0.16,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284504400,
#   Timestamp('1979-01-06 21:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.64,
#   9.2,
#   12.15,
#   10.21,
#   1022,
#   94,
#   9.72,
#   5.9,
#   50,
#   nan,
#   89,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284508000,
#   Timestamp('1979-01-06 22:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.54,
#   9.03,
#   12.06,
#   10.1,
#   1023,
#   94,
#   9.62,
#   5.96,
#   47,
#   nan,
#   84,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   284511600,
#   Timestamp('1979-01-06 23:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.02,
#   9.02,
#   10.74,
#   9.53,
#   1023,
#   94,
#   9.1,
#   6.3,
#   46,
#   nan,
#   90,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284515200,
#   Timestamp('1979-01-07 00:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.81,
#   9.23,
#   12.36,
#   10.4,
#   1023,
#   94,
#   9.88,
#   6.39,
#   48,
#   nan,
#   91,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284518800,
#   Timestamp('1979-01-07 01:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.11,
#   9.1,
#   10.77,
#   9.66,
#   1023,
#   95,
#   9.35,
#   6.31,
#   50,
#   nan,
#   89,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284522400,
#   Timestamp('1979-01-07 02:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.55,
#   9.96,
#   13.15,
#   11.16,
#   1024,
#   92,
#   10.3,
#   6.43,
#   52,
#   nan,
#   91,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284526000,
#   Timestamp('1979-01-07 03:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.59,
#   9.99,
#   13.21,
#   11.21,
#   1023,
#   92,
#   10.34,
#   6.36,
#   53,
#   nan,
#   95,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284529600,
#   Timestamp('1979-01-07 04:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.43,
#   9.88,
#   13.03,
#   11.03,
#   1023,
#   92,
#   10.18,
#   6.3,
#   53,
#   nan,
#   99,
#   0.58,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284533200,
#   Timestamp('1979-01-07 05:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.86,
#   9.8,
#   11.6,
#   10.38,
#   1023,
#   91,
#   9.45,
#   5.99,
#   55,
#   nan,
#   100,
#   0.37,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284536800,
#   Timestamp('1979-01-07 06:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.76,
#   9.67,
#   11.49,
#   10.29,
#   1024,
#   92,
#   9.51,
#   5.65,
#   58,
#   nan,
#   98,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   284540400,
#   Timestamp('1979-01-07 07:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.32,
#   9.66,
#   12.97,
#   10.91,
#   1024,
#   92,
#   10.07,
#   5.86,
#   57,
#   nan,
#   98,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284544000,
#   Timestamp('1979-01-07 08:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   8.8,
#   7.79,
#   9.37,
#   5.82,
#   1025,
#   91,
#   7.41,
#   5.71,
#   57,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284547600,
#   Timestamp('1979-01-07 09:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.13,
#   10.61,
#   13.66,
#   11.72,
#   1025,
#   89,
#   10.37,
#   5.72,
#   56,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284551200,
#   Timestamp('1979-01-07 10:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.73,
#   10.24,
#   13.19,
#   11.31,
#   1025,
#   90,
#   10.15,
#   6.62,
#   56,
#   nan,
#   100,
#   0.1,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10d',
#   None,
#   284554800,
#   Timestamp('1979-01-07 11:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.83,
#   9.87,
#   11.67,
#   10.29,
#   1025,
#   89,
#   9.09,
#   6.37,
#   51,
#   nan,
#   99,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   284558400,
#   Timestamp('1979-01-07 12:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.05,
#   9.67,
#   12.46,
#   10.59,
#   1024,
#   91,
#   9.64,
#   6.36,
#   53,
#   nan,
#   99,
#   0.15,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10d',
#   None,
#   284562000,
#   Timestamp('1979-01-07 13:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.17,
#   9.73,
#   12.59,
#   10.8,
#   1024,
#   94,
#   10.24,
#   6.44,
#   54,
#   nan,
#   97,
#   0.86,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10d',
#   None,
#   284565600,
#   Timestamp('1979-01-07 14:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.3,
#   9.53,
#   11.07,
#   9.89,
#   1024,
#   96,
#   9.69,
#   6.16,
#   54,
#   nan,
#   97,
#   0.64,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10d',
#   None,
#   284569200,
#   Timestamp('1979-01-07 15:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.57,
#   9.77,
#   11.3,
#   10.19,
#   1023,
#   96,
#   9.96,
#   5.59,
#   52,
#   nan,
#   90,
#   1.31,
#   nan,
#   nan,
#   nan,
#   501,
#   'Rain',
#   'moderate rain',
#   '10d',
#   None,
#   284572800,
#   Timestamp('1979-01-07 16:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.98,
#   10.14,
#   11.71,
#   10.64,
#   1023,
#   96,
#   10.37,
#   5.07,
#   43,
#   nan,
#   91,
#   2.19,
#   nan,
#   nan,
#   nan,
#   501,
#   'Rain',
#   'moderate rain',
#   '10n',
#   None,
#   284576400,
#   Timestamp('1979-01-07 17:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.35,
#   10.48,
#   12.11,
#   11.02,
#   1023,
#   95,
#   10.58,
#   4.92,
#   41,
#   nan,
#   92,
#   1.18,
#   nan,
#   nan,
#   nan,
#   501,
#   'Rain',
#   'moderate rain',
#   '10n',
#   None,
#   284580000,
#   Timestamp('1979-01-07 18:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.46,
#   10.64,
#   12.23,
#   11.12,
#   1023,
#   94,
#   10.53,
#   4.8,
#   42,
#   nan,
#   97,
#   0.12,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284583600,
#   Timestamp('1979-01-07 19:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.58,
#   10.82,
#   12.38,
#   11.25,
#   1023,
#   94,
#   10.65,
#   4.49,
#   43,
#   nan,
#   95,
#   0.59,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284587200,
#   Timestamp('1979-01-07 20:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.18,
#   9.02,
#   11.81,
#   9.76,
#   1023,
#   96,
#   9.57,
#   4.2,
#   35,
#   nan,
#   99,
#   0.51,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284590800,
#   Timestamp('1979-01-07 21:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.03,
#   10.24,
#   11.72,
#   10.7,
#   1023,
#   96,
#   10.42,
#   4.33,
#   24,
#   nan,
#   100,
#   0.83,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   284594400,
#   Timestamp('1979-01-07 22:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.95,
#   10.07,
#   11.67,
#   10.58,
#   1023,
#   95,
#   10.18,
#   4.16,
#   24,
#   nan,
#   94,
#   1.6,
#   nan,
#   nan,
#   nan,
#   501,
#   'Rain',
#   'moderate rain',
#   '10n',
#   None,
#   284598000,
#   Timestamp('1979-01-07 23:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.97,
#   10.07,
#   11.69,
#   10.63,
#   1022,
#   96,
#   10.36,
#   3.92,
#   21,
#   nan,
#   94,
#   2.1,
#   nan,
#   nan,
#   nan,
#   501,
#   'Rain',
#   'moderate rain',
#   '10n',
#   None,
#   284601600,
#   Timestamp('1979-01-08 00:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   10.93,
#   10.07,
#   11.66,
#   10.56,
#   1022,
#   95,
#   10.16,
#   3.78,
#   17,
#   nan,
#   91,
#   1.87,
#   nan,
#   nan,
#   nan,
#   501,
#   'Rain',
#   'moderate rain',
#   '10n',
#   None,
#   284605200,
# ...
#   -0.506159,
#   13.93,
#   12.9,
#   14.66,
#   13.1,
#   1008,
#   66,
#   7.69,
#   1.07,
#   296,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287395200,
#   Timestamp('1979-02-09 08:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.42,
#   13.45,
#   17.43,
#   14.71,
#   1008,
#   65,
#   8.88,
#   0.88,
#   301,
#   nan,
#   99,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287398800,
#   Timestamp('1979-02-09 09:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   21.66,
#   19.24,
#   23.97,
#   21.27,
#   1008,
#   53,
#   11.68,
#   0.46,
#   227,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287402400,
#   Timestamp('1979-02-09 10:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   20.49,
#   18.55,
#   22.07,
#   20.0,
#   1009,
#   54,
#   10.87,
#   1.23,
#   218,
#   nan,
#   99,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287406000,
#   Timestamp('1979-02-09 11:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   20.23,
#   18.05,
#   22.16,
#   19.69,
#   1008,
#   53,
#   10.35,
#   1.81,
#   209,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287409600,
#   Timestamp('1979-02-09 12:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   19.92,
#   17.54,
#   22.13,
#   19.4,
#   1006,
#   55,
#   10.62,
#   2.06,
#   206,
#   nan,
#   97,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287413200,
#   Timestamp('1979-02-09 13:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   19.9,
#   17.07,
#   22.09,
#   19.43,
#   1005,
#   57,
#   11.14,
#   2.05,
#   199,
#   nan,
#   86,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287416800,
#   Timestamp('1979-02-09 14:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   17.99,
#   15.73,
#   20.02,
#   17.52,
#   1004,
#   64,
#   11.09,
#   2.29,
#   188,
#   nan,
#   81,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04d',
#   None,
#   287420400,
#   Timestamp('1979-02-09 15:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   17.88,
#   15.71,
#   19.74,
#   17.45,
#   1004,
#   66,
#   11.45,
#   2.22,
#   184,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287424000,
#   Timestamp('1979-02-09 16:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   17.23,
#   15.07,
#   19.07,
#   16.91,
#   1004,
#   73,
#   12.35,
#   1.74,
#   176,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287427600,
#   Timestamp('1979-02-09 17:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   17.01,
#   13.33,
#   18.98,
#   16.65,
#   1003,
#   72,
#   11.93,
#   1.45,
#   181,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   287431200,
#   Timestamp('1979-02-09 18:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   18.28,
#   15.64,
#   20.25,
#   17.89,
#   1003,
#   66,
#   11.83,
#   1.87,
#   194,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   287434800,
#   Timestamp('1979-02-09 19:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   18.55,
#   16.14,
#   20.57,
#   18.13,
#   1002,
#   64,
#   11.62,
#   2.89,
#   225,
#   nan,
#   97,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   287438400,
#   Timestamp('1979-02-09 20:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   14.75,
#   13.05,
#   16.36,
#   14.08,
#   1002,
#   69,
#   9.13,
#   3.27,
#   233,
#   nan,
#   71,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   287442000,
#   Timestamp('1979-02-09 21:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   14.53,
#   12.65,
#   16.38,
#   13.79,
#   1002,
#   67,
#   8.48,
#   3.5,
#   241,
#   nan,
#   41,
#   nan,
#   nan,
#   nan,
#   nan,
#   802,
#   'Clouds',
#   'scattered clouds',
#   '03n',
#   None,
#   287445600,
#   Timestamp('1979-02-09 22:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   14.5,
#   12.84,
#   16.23,
#   13.7,
#   1002,
#   65,
#   8.01,
#   4.09,
#   248,
#   nan,
#   49,
#   nan,
#   nan,
#   nan,
#   nan,
#   802,
#   'Clouds',
#   'scattered clouds',
#   '03n',
#   None,
#   287449200,
#   Timestamp('1979-02-09 23:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   14.26,
#   12.78,
#   15.73,
#   13.33,
#   1002,
#   61,
#   6.85,
#   3.99,
#   251,
#   nan,
#   79,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   287452800,
#   Timestamp('1979-02-10 00:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   14.58,
#   13.19,
#   15.8,
#   13.63,
#   1002,
#   59,
#   6.67,
#   4.32,
#   255,
#   nan,
#   38,
#   nan,
#   nan,
#   nan,
#   nan,
#   802,
#   'Clouds',
#   'scattered clouds',
#   '03n',
#   None,
#   287456400,
#   Timestamp('1979-02-10 01:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   14.51,
#   13.07,
#   15.37,
#   13.58,
#   1003,
#   60,
#   6.85,
#   4.33,
#   263,
#   nan,
#   11,
#   nan,
#   nan,
#   nan,
#   nan,
#   801,
#   'Clouds',
#   'few clouds',
#   '02n',
#   None,
#   287460000,
#   Timestamp('1979-02-10 02:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   13.78,
#   12.07,
#   14.56,
#   12.7,
#   1002,
#   57,
#   5.42,
#   4.46,
#   268,
#   nan,
#   7,
#   nan,
#   nan,
#   nan,
#   nan,
#   800,
#   'Clear',
#   'sky is clear',
#   '01n',
#   None,
#   287463600,
#   Timestamp('1979-02-10 03:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   13.55,
#   12.07,
#   14.45,
#   12.48,
#   1003,
#   58,
#   5.45,
#   4.33,
#   269,
#   nan,
#   15,
#   nan,
#   nan,
#   nan,
#   nan,
#   801,
#   'Clouds',
#   'few clouds',
#   '02n',
#   None,
#   287467200,
#   Timestamp('1979-02-10 04:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   13.23,
#   11.89,
#   14.38,
#   12.18,
#   1004,
#   60,
#   5.64,
#   4.01,
#   267,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   287470800,
#   Timestamp('1979-02-10 05:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.33,
#   12.07,
#   12.86,
#   11.26,
#   1004,
#   63,
#   5.5,
#   3.8,
#   269,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   287474400,
#   Timestamp('1979-02-10 06:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.99,
#   11.53,
#   14.4,
#   11.99,
#   1004,
#   63,
#   6.12,
#   3.25,
#   263,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287478000,
#   Timestamp('1979-02-10 07:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.89,
#   11.49,
#   14.18,
#   11.91,
#   1005,
#   64,
#   6.25,
#   3.25,
#   258,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287481600,
#   Timestamp('1979-02-10 08:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   13.48,
#   12.2,
#   14.41,
#   12.66,
#   1005,
#   68,
#   7.7,
#   2.51,
#   247,
#   nan,
#   99,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287485200,
#   Timestamp('1979-02-10 09:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   16.49,
#   15.08,
#   17.32,
#   15.74,
#   1005,
#   59,
#   8.46,
#   2.49,
#   250,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287488800,
#   Timestamp('1979-02-10 10:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   16.78,
#   15.32,
#   17.68,
#   16.08,
#   1005,
#   60,
#   8.98,
#   3.11,
#   215,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287492400,
#   Timestamp('1979-02-10 11:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   16.84,
#   15.28,
#   17.96,
#   16.15,
#   1003,
#   60,
#   9.04,
#   2.91,
#   196,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287496000,
#   Timestamp('1979-02-10 12:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   16.37,
#   14.63,
#   17.83,
#   15.76,
#   1002,
#   65,
#   9.78,
#   2.84,
#   187,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287499600,
#   Timestamp('1979-02-10 13:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   16.85,
#   15.07,
#   17.42,
#   16.39,
#   1001,
#   69,
#   11.13,
#   3.09,
#   177,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287503200,
#   Timestamp('1979-02-10 14:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.76,
#   15.07,
#   16.4,
#   15.51,
#   1000,
#   81,
#   12.51,
#   3.13,
#   181,
#   nan,
#   83,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04d',
#   None,
#   287506800,
#   Timestamp('1979-02-10 15:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.77,
#   15.07,
#   16.45,
#   15.6,
#   1000,
#   84,
#   13.08,
#   3.43,
#   182,
#   nan,
#   86,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287510400,
#   Timestamp('1979-02-10 16:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.94,
#   14.07,
#   16.54,
#   15.84,
#   999,
#   86,
#   13.6,
#   3.56,
#   192,
#   nan,
#   75,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04d',
#   None,
#   287514000,
#   Timestamp('1979-02-10 17:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.0,
#   13.07,
#   16.47,
#   14.91,
#   999,
#   90,
#   13.37,
#   2.2,
#   191,
#   nan,
#   62,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   287517600,
#   Timestamp('1979-02-10 18:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   14.44,
#   12.74,
#   15.85,
#   14.37,
#   998,
#   93,
#   13.32,
#   1.82,
#   179,
#   nan,
#   80,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   287521200,
#   Timestamp('1979-02-10 19:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   14.55,
#   12.97,
#   15.64,
#   14.46,
#   998,
#   92,
#   13.27,
#   1.55,
#   181,
#   nan,
#   91,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   287524800,
#   Timestamp('1979-02-10 20:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   13.07,
#   12.07,
#   13.36,
#   12.89,
#   997,
#   94,
#   12.13,
#   1.1,
#   190,
#   nan,
#   55,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   287528400,
#   Timestamp('1979-02-10 21:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.55,
#   10.99,
#   13.74,
#   12.26,
#   996,
#   92,
#   11.29,
#   2.96,
#   217,
#   nan,
#   51,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   287532000,
#   Timestamp('1979-02-10 22:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.24,
#   10.68,
#   13.4,
#   11.87,
#   995,
#   90,
#   10.65,
#   3.18,
#   228,
#   nan,
#   28,
#   nan,
#   nan,
#   nan,
#   nan,
#   802,
#   'Clouds',
#   'scattered clouds',
#   '03n',
#   None,
#   287535600,
#   Timestamp('1979-02-10 23:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.27,
#   10.79,
#   13.44,
#   11.9,
#   994,
#   90,
#   10.68,
#   3.04,
#   225,
#   nan,
#   65,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   287539200,
#   Timestamp('1979-02-11 00:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.68,
#   11.96,
#   13.39,
#   12.33,
#   994,
#   89,
#   10.92,
#   2.84,
#   234,
#   nan,
#   88,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   287542800,
#   Timestamp('1979-02-11 01:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.28,
#   10.61,
#   13.85,
#   11.84,
#   994,
#   87,
#   10.18,
#   2.68,
#   240,
#   nan,
#   95,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04n',
#   None,
#   287546400,
#   Timestamp('1979-02-11 02:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.29,
#   10.07,
#   13.59,
#   11.82,
#   993,
#   86,
#   10.02,
#   2.43,
#   232,
#   nan,
#   100,
#   1.06,
#   nan,
#   nan,
#   nan,
#   501,
#   'Rain',
#   'moderate rain',
#   '10n',
#   None,
#   287550000,
#   Timestamp('1979-02-11 03:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.6,
#   11.46,
#   13.3,
#   12.14,
#   991,
#   85,
#   10.15,
#   1.56,
#   170,
#   nan,
#   100,
#   0.76,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10n',
#   None,
#   287553600,
#   Timestamp('1979-02-11 04:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.06,
#   10.81,
#   13.12,
#   11.65,
#   991,
#   89,
#   10.3,
#   2.51,
#   203,
#   nan,
#   82,
#   nan,
#   nan,
#   nan,
#   nan,
#   803,
#   'Clouds',
#   'broken clouds',
#   '04n',
#   None,
#   287557200,
#   Timestamp('1979-02-11 05:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.73,
#   10.59,
#   12.59,
#   11.36,
#   991,
#   92,
#   10.47,
#   2.32,
#   223,
#   nan,
#   28,
#   nan,
#   nan,
#   nan,
#   nan,
#   802,
#   'Clouds',
#   'scattered clouds',
#   '03n',
#   None,
#   287560800,
#   Timestamp('1979-02-11 06:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.21,
#   9.33,
#   12.22,
#   10.84,
#   991,
#   94,
#   10.28,
#   2.61,
#   225,
#   nan,
#   13,
#   nan,
#   nan,
#   nan,
#   nan,
#   801,
#   'Clouds',
#   'few clouds',
#   '02d',
#   None,
#   287564400,
#   Timestamp('1979-02-11 07:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   11.41,
#   10.29,
#   12.21,
#   11.03,
#   991,
#   93,
#   10.32,
#   3.26,
#   215,
#   nan,
#   46,
#   nan,
#   nan,
#   nan,
#   nan,
#   802,
#   'Clouds',
#   'scattered clouds',
#   '03d',
#   None,
#   287568000,
#   Timestamp('1979-02-11 08:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   12.32,
#   10.87,
#   13.47,
#   11.88,
#   991,
#   87,
#   10.22,
#   4.27,
#   214,
#   nan,
#   88,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287571600,
#   Timestamp('1979-02-11 09:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.3,
#   13.59,
#   16.71,
#   14.84,
#   992,
#   75,
#   10.9,
#   4.64,
#   218,
#   nan,
#   91,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287575200,
#   Timestamp('1979-02-11 10:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   15.52,
#   13.78,
#   16.94,
#   15.03,
#   991,
#   73,
#   10.71,
#   4.81,
#   218,
#   nan,
#   98,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287578800,
#   Timestamp('1979-02-11 11:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   16.26,
#   14.07,
#   17.57,
#   15.69,
#   991,
#   67,
#   10.13,
#   4.95,
#   230,
#   nan,
#   99,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287582400,
#   Timestamp('1979-02-11 12:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   16.53,
#   15.01,
#   17.71,
#   15.88,
#   990,
#   63,
#   9.47,
#   4.5,
#   245,
#   nan,
#   99,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287586000,
#   Timestamp('1979-02-11 13:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   16.8,
#   15.46,
#   17.73,
#   16.1,
#   990,
#   60,
#   9.0,
#   4.33,
#   254,
#   nan,
#   100,
#   nan,
#   nan,
#   nan,
#   nan,
#   804,
#   'Clouds',
#   'overcast clouds',
#   '04d',
#   None,
#   287589600,
#   Timestamp('1979-02-11 14:00:00+0000', tz='UTC'),
#   3600),
#  ('Sant Antoni',
#   38.553135,
#   -0.506159,
#   14.46,
#   14.21,
#   15.07,
#   13.71,
#   990,
#   67,
#   8.42,
#   4.06,
#   258,
#   nan,
#   99,
#   0.23,
#   nan,
#   nan,
#   nan,
#   500,
#   'Rain',
#   'light rain',
#   '10d',
#   None,
#   287593200,
#   Timestamp('1979-02-11 15:00:00+0000', tz='UTC'),
#   3600),
#  ...]
